# %%
import os, sys
module_path = os.path.abspath(os.path.join('/global/common/software/ProjectDisCo/'))
sys.path.append(module_path)

import numpy as np
from source.visuals import *

# %matplotlib inline

# %%
datadir = '/global/project/projectdirs/ProjectDisCo/Jupiter/gs_arrays/'
jup_field = np.load(datadir+'jup_gs_110.npy')

# %%
diagram(jup_field[600:-500, 200:1800].astype(np.float32), cmap=plt.cm.YlOrRd, ticks=False)
plt.savefig('jupiter.pdf', bbox_inches='tight')

# %%
lcsdir = "/global/project/projectdirs/ProjectDisCo/Adam/jupiter/results/result-3/fields/"
lcsfiles = sorted(os.listdir(lcsdir))

# %%
field = np.load(lcsdir+lcsfiles[80])

# %%
diagram(field[0, 200:-100, 200:-400], ticks=False, cmap=plt.cm.tab10)
plt.savefig('jup_states-3.pdf', bbox_inches='tight')

# %%
lcsdir = "/global/project/projectdirs/ProjectDisCo/Adam/jupiter/results/result-4/fields/"
lcsfiles = sorted(os.listdir(lcsdir))

# %%
field = np.load(lcsdir+lcsfiles[80])

# %%
diagram(field[0, 200:-100, 200:-400], ticks=False, cmap=plt.cm.tab10)
plt.savefig('jup_states-4.pdf', bbox_inches='tight')

# %%
lcsdir = "/global/project/projectdirs/ProjectDisCo/Adam/jupiter/results/result-9/fields/"
lcsfiles = sorted(os.listdir(lcsdir))

# %%
field = np.load(lcsdir+lcsfiles[80])

# %%
diagram(field[0, 200:-100, 200:-400], ticks=False, cmap=plt.cm.tab20)
plt.savefig('jup_states-9.pdf', bbox_inches='tight')
